# %% [markdown]
# ## 01. PyTorch and Numpy (Part 3)
#
# - Resource notebook: https://www.learnpytorch.io/00_pytorch_fundamentals/
# - If you have a question: https://github.com/mrdbourke/pytorch-deep-learning/discussions
# - YouTube Link: https://youtu.be/LyJtbe__2i0?si=pX28SzDmaqsiu3Y4

# %% [markdown]
# ### Running tensors and PyTorch objects on the GPUs (and making faster computation)
#
# GPUs = faster computations on numbers, thanks to CUDA + NVIDIA hardware + PyTorch working behind the scenes to make everything good.
# Vanilla Numpy runs on CPU

# %% [markdown]
# #### 1 . Getting a GPU
#
# 1. Easiest: Use Google Colab for free GPU
# 2. Use your own GPU - take a little bit of setup and requires investment of purchasing
# 3. Use Cloud Computing - GCP, AWS, Azure, these services allow you to rent computers on the cloud and access them
#
# For 2, 3 PyTorch + GPU Drivers (CUDA) takes a little bit of setting up, to do this, refer to PyTorch setup documentation

# %%
# !nvidia-smi

# %% [markdown]
# #### 2. Check for GPU access with PyTorch
#
# CUDA is NVIDIA programming interface that allows us to use GPUs for numeric computing

# %%
import torch
torch.cuda.is_available()

# %%
# Setup device-agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device

# %% [markdown]
# For PyTorch since it's capable of running compute on the GPU or CPU, it's best practice to setup device agnostic code: https://pytorch.org/docs/stable/notes/cuda.html#best-practices

# %%
torch.cuda.device_count()

# %% [markdown]
# #### 3. Putting tensors (and models) on the GPU
# The reason we want out tensors/models on the GPU is because using a GPU results in faster computations.

# %%
tensor = torch.tensor([1,2,3])
print(tensor, tensor.device)

# %%
# Move tensor to GPU (if available)
tensor_on_gpu = tensor.to(device)
tensor_on_gpu

# %% [markdown]
# #### 4. Moving tensors back to CPU
#
# If tensor is on GPU, can't transform it to NumPy

# %%
# tensor_on_gpu.numpy() throws error because tensor is on GPU, need to move it back to CPU first
tensor_back_on_cpu = tensor_on_gpu.cpu().numpy()
tensor_back_on_cpu

# %% [markdown]
# ## Exercises and Extra Curriculum
#
# See exercises for this notebook here: https://www.learnpytorch.io/00_pytorch_fundamentals/#exercises
