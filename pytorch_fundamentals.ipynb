# %% [markdown]
# ## 00. PyTorch Fundamentals
#
# - Resource notebook: https://www.learnpytorch.io/00_pytorch_fundamentals/
# - If you have a question: https://github.com/mrdbourke/pytorch-deep-learning/discussions
# - YouTube Link: https://youtu.be/LyJtbe__2i0?si=pX28SzDmaqsiu3Y4

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(torch.__version__)

# %% [markdown]
# ### Introduction to Tensors
#
# ##### Creating tensors
#
# Pytorch tensors are created using torch.Tensor() = https://pytorch.org/docs/stable/tensors.html

# %%
# scalar
scalar = torch.tensor(7)
scalar

# %%
# Get Tensor Back as Python Number
scalar.item()

# %%
vector = torch.tensor([7, 7])
vector

# %%
vector.ndim # 1
vector.shape

# %%
# MATRIX
MATRIX = torch.tensor([[7, 8],
                       [9, 10]])
MATRIX

# %%
MATRIX.ndim # 2
MATRIX.shape

# %%
# TENSOR
TENSOR = torch.tensor([[[1,2,3],
                        [3,6,9],
                        [2,4,6]]])
TENSOR

# %%
TENSOR.ndim # 3
TENSOR.shape

# %% [markdown]
# ### Random tensors
#
# Why random tensors?
#
# Random tensors are important because the way many neural networks learn is that they start with tensors full of random numbers and then adjust those random numbers to better represent the data.
#
# `Start with random numbers -> look at data -> update random numbers -> look at data -> update random numbers`
#
# Torch random tensors = https://pytorch.org/docs/stable/generated/torch.rand.html

# %%
# Create a random tensor of size 
random_tensor = torch.rand(3, 4)
random_tensor

# %%
random_tensor.ndim
random_tensor.shape

# %%
# Create a random tensor with similar shape to an image tensor
random_image_size_tensor = torch.rand(size=(224, 224, 3)) # height, width, color channels
random_image_size_tensor.shape, random_image_size_tensor.ndim

# %% [markdown]
# ### Zeros and Ones

# %%
# Create a tensor of all zeros
zeros = torch.zeros(size=(3,4))
zeros

# %%
# zeros*random_tensor # makes 0
ones = torch.ones(size=(3,4))
ones

# %%
ones.dtype # datatype

# %% [markdown]
# ### Creating a range of tensors and tensors-like
#
# **Note:** Tensor datatypes is one of the 3 big errors you'll run into with PyTorch & deep learning
#
# 1. Tensors not right datatype (can use tensor.dtype)
# 2. Tensors not right shape (can use tensor.shape)
# 3. Tensors not on the right device (can use tensor.device)
#
# Precision in computing: See Wikipedia

# %%
# Use torch.range() and get deprecated warning, use torch.arange() instead
one_to_ten = torch.arange(start=1, end=1000, step=99)
one_to_ten

# %%
ten_zeros = torch.zeros_like(input=one_to_ten)
ten_zeros

# %% [markdown]
# ### Tensor datatypes

# %%
# Float 32 tensor (By default, PyTorch uses float 32)
float_32_tensor = torch.tensor([3.0, 6.0, 9.0], dtype=None, device=None, requires_grad=False)
float_32_tensor, float_32_tensor.dtype

# %%
float_16_tensor = float_32_tensor.type(torch.float16)
float_16_tensor, float_16_tensor.dtype

# %%
float_16_tensor * float_32_tensor

# %%
int_64_tensor = torch.tensor([3, 6, 9], dtype=torch.long)
int_64_tensor, int_64_tensor.dtype

# %%
float_32_tensor * int_64_tensor

# %%
# Find out details some tensor
some_tensor = torch.rand(3,4)
print(some_tensor)
print(f"Datatype of tensor: {some_tensor.dtype}")
print(f"Shape of tensor: {some_tensor.shape}")
print(f"Number of dimensions of tensor: {some_tensor.ndim}")
print(f"Device tensor is on: {some_tensor.device}")

# %% [markdown]
# ### Manipulating Tensors (tensor operations)
#
# Tensor operations include:
# 1. Addition
# 2. Subtraction
# 3. Multiplication (element-wise)
# 4. Division
# 5. Matrix multiplication

# %%
# Create a tensor and add 10 to it
tensor = torch.tensor([1, 2, 3])
tensor + 10

# %%
# Multiply tensor by 10
tensor * 10

# %%
tensor - 10

# %%
torch.mul(tensor, 10)

# %%
torch.add(tensor, 10)

# %% [markdown]
# ### Matrix Multiplication
#
# Two main ways of performing multiplication in neural networks and deep learning
#
# 1. Element-wise multiplication
# 2. Matrix Multiplication (dot product)

# %%
# Element wise multiplication
print (tensor * tensor)
print (f"Equals: {tensor * tensor}")

# %%
# Matrix Multiplication, we have %%time to see how long it takes
torch.matmul(tensor, tensor) # dot product, we can write torch.mm(tensor, tensor) as well

# %% [markdown]
# - To fix our tensor shape issues in matrix multiplication, we can manipulate the shape of one of our tensors using a **tensors**
# - A **transpose** switches the axes or dimensions of a given tensor.

# %%
tensor_A = torch.arange(1, 10).reshape(3, 3)
tensor_B = torch.arange(1, 7).reshape(2, 3)
tensor_A.shape, tensor_B.shape

# %%
torch.mm(tensor_A, tensor_B.T)

# %% [markdown]
# ## Finding min, max, mean, sum, etc (tensor aggregation)

# %%
# Create a tensor
x = torch.arange(0, 100, 10)
x

# %%
torch.min(x), x.min()

# %%
torch.max(x), x.max()

# %%
# torch.mean() function requires a tensor of float32 datatype to work
torch.mean(x.type(torch.float32)), x.type(torch.float32).mean()

# %% [markdown]
# ### Finding the positional min and max

# %%
x

# %%
# Find the position in tensor that has min value with argmin() -> return index position of minimum value
x.argmin() # at 0th position, we have minimum value which is 0

# %%
x.argmax() # at 9th position, we have maximum value which is 90

# %% [markdown]
# ### Reshaping, stacking, squeezing and unsqueezing tensors
#
# - Reshaping - reshapes an input tensor to a defined shape
# - View - Return a view of an input tensor of certain shape but keep the same memory as the original tensor
# - Stacking - combine multiple tensors on top of each other (vertical stack (vstack)) or side by side (hstack -> horizontal stack)
# - Squeeze - removes all `1` dimensions from a tensor
# - Unsqueeze - add a `1` dimension to a target tensor
# - Permute - Return a view of the input with dimensions permuted (swapped) in a certain way

# %%
# Let's create a tensor
import torch
x = torch.arange(1., 10.)
x, x.shape

# %%
# Add an extra dimension
x_reshaped = x.reshape(1, 9) # 1 * 9 = 9 elements
x_reshaped, x_reshaped.shape
# x_reshaped = x.reshape(9, 1) # this is also possible as multiplies to 9 elements

# %%
# Change the view
z = x.view(1, 9) # view is same as reshape but view shares memory with original tensor, z is same view of x
z, z.shape

# %%
# Changing z changes x (because a view of a tensor shares the same memory as the original tensor)
z[:, 0] = 5
z, x

# %%
# Stack tensors on top of each other
x_stacked = torch.stack([x, x, x, x], dim=0)
# stack along the 0th dimension (rows) for dim = 0, for columns dim = 1
x_stacked, x_stacked.shape

# %%
x_reshaped.shape

# %%
new_x_reshaped = x_reshaped.squeeze() # removes all dimensions of size 1
new_x_reshaped.shape

# %%
new_x_reshaped.unsqueeze(0) # adds an extra dimension at 0th position

# %%
# torch.permute - rearranges the dimensions of a target tensor in a specified order
x_original = torch.rand(size=(224, 224, 3)) # height, width, color channels

# Permute the original tensor to rearrange the axis (or dim) order
x_permuted = x_original.permute(2, 0, 1) # shifts axis 0 -> 1, 1 -> 2, 2 -> 0
# Permuted also use same memory as original_tensor

print(f"Previous shape: {x_original.shape}")
print(f"New shape: {x_permuted.shape}")

# %% [markdown]
# ### Indexing (selecting data from tensors)
# Indexing with PyTorch is similiar to indexing with NumPy

# %%
# Create a tensor
import torch
x = torch.arange(1, 10).reshape(1,3,3)
x, x.shape

# %%
# Let's index on our new tensor
x[0]

# %%
x[0][0] # first row of the first matrix, same as x[0, 0], (dim=1)

# %%
# Lets index on the most inner bracket (last dimension)
x[0][0][0]

# %%
# We can use ':' to select all of a particular dimension
x[:, 0] # all of the 0th dimension, first row of all matrices

# %%
# Get all values of 0th and 1st dimensions but only index 1 of 2nd dimension
x[:, :, 1]

# %%
x[:, 1, 1]
